# %%
# !yolo train data=data.yaml model=yolov8n.pt batch=4 epochs=25 imgsz=1674 workers=0
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
# !yolo val data=data.yaml model='runs/detect/train2/weights/best.pt' batch=4 imgsz=1674
# Out:
# WARNING ⚠️ imgsz=[1674] must be multiple of max stride 32, updating to [1696]
# Ultralytics YOLOv8.0.203 🚀 Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/nikhil/projects/traffic violation detection/Seatbelt/valid/l
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         95        223      0.777      0.877      0.889      0.564
#      person-noseatbelt         95         47      0.821      0.915      0.945      0.668
#        person-seatbelt         95         88      0.851      0.943      0.971      0.682
#               seatbelt         95         88       0.66      0.773      0.751      0.342
# Speed: 9.6ms preprocess, 24.9ms inference, 0.0ms loss, 9.2ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo val data=data.yaml model='runs/detect/train2/weights/best.pt' split=test
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/nikhil/projects/traffic violation detection/Seatbelt/test/la
# val: New cache created: /home/nikhil/projects/traffic violation detection/Seatbelt/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all          7         14      0.871      0.933      0.951      0.597
#      person-noseatbelt          7          4      0.866          1      0.995       0.67
#        person-seatbelt          7          5      0.763          1      0.962      0.753
#               seatbelt          7          5      0.985        0.8      0.895      0.367
# Speed: 27.6ms preprocess, 69.5ms inference, 0.0ms loss, 87.1ms postprocess per image
# Results saved to runs/detect/val5
# ...

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %%
model = YOLO('runs/detect/train2/weights/best.pt')

# %%
result = model.predict(source='20180406122924_E-challan-generation-1.jpg',show=True)
print(result)
# Out:
# image 1/1 \\wsl.localhost\Ubuntu\home\nikhil\projects\traffic violation detection\Seatbelt\20180406122924_E-challan-generation-1.jpg: 608x1696 (no detections), 264.1ms
# Speed: 10.5ms preprocess, 264.1ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 1696)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: '1', 1: '2', 2: 'person-noseatbelt', 3: 'person-seatbelt', 4: 'seatbelt'}
# orig_img: array([[[ 41,  25,  13],
#         [ 45,  29,  17],
#         [ 52,  36,  24],
#         ...,
#         [105,  91,  85],
#         [ 58,  46,  40],
#         [ 48,  38,  31]],
#
#        [[ 16,   1,   0],
#         [ 21,   6,   0],
#         [ 34,  19,  10],
#         ...,
#         [103,  89,  83],
#         [ 44,  32,  26],
#         [ 46,  38,  31]],
#
#        [[ 28,  18,  11],
#         [ 29,  19,  12],
#         [ 36,  26,  19],
#         ...,
#         [ 72,  60,  54],
# ...

# %%
import cv2
# video_capture = cv2.VideoCapture("BAD DRIVERS He Owns The Road Daily Observations India #74.mp4")
video_capture = cv2.VideoCapture(1)

cv2.namedWindow("Window")

while True:
    ret, frame = video_capture.read()

    result = model(frame)
    

    cv2.imshow("Window", result[0].plot())
    #This breaks on 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video_capture.release()
cv2.destroyAllWindows()
# Out:
# 0: 960x1696 (no detections), 612.9ms
# Speed: 41.3ms preprocess, 612.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1696)
#
# 0: 960x1696 (no detections), 523.3ms
# Speed: 33.8ms preprocess, 523.3ms inference, 3.0ms postprocess per image at shape (1, 3, 960, 1696)
#
# 0: 960x1696 (no detections), 524.9ms
# Speed: 33.8ms preprocess, 524.9ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 1696)
#
# 0: 960x1696 (no detections), 515.9ms
# Speed: 32.3ms preprocess, 515.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1696)
#
# 0: 960x1696 (no detections), 531.7ms
# Speed: 33.8ms preprocess, 531.7ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1696)
#
# 0: 960x1696 2 person-seatbelts, 549.1ms
# Speed: 31.4ms preprocess, 549.1ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 1696)
#
# 0: 960x1696 (no detections), 548.0ms
# ...
