# %%
# !yolo detect train data='data.yaml' model=yolov8n.pt epochs=25 imgsz=496

# %%
# !yolo detect train data='data.yaml' epochs=50 imgsz=496 model=yolov8n.yaml pretrained=yolov8n.pt
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
import torch

# %%
# !yolo val data=data.yaml model='runs/detect/train4/weights/best.pt' batch=4 imgsz=496
# Out:
# WARNING ⚠️ imgsz=[496] must be multiple of max stride 32, updating to [512]
# Ultralytics YOLOv8.0.203 🚀 Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/nikhil/projects/traffic violation detection/Helmet/valid/lab
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        153        303      0.738      0.714      0.735      0.461
#            With Helmet        153        172      0.819      0.826      0.856      0.582
#         Without Helmet        153        131      0.658      0.603      0.614       0.34
# Speed: 0.3ms preprocess, 13.2ms inference, 0.0ms loss, 3.5ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo predict model='runs/detect/train4/weights/best.pt' source="Screenshot 2023-11-02 162111.png"
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /home/nikhil/projects/traffic violation detection/Helmet/Screenshot 2023-11-02 162111.png: 512x416 1 With Helmet, 129.5ms
# Speed: 4.7ms preprocess, 129.5ms inference, 423.7ms postprocess per image at shape (1, 3, 512, 416)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %%
model = YOLO('runs/detect/train4/weights/best.pt')

# %%
result = model.predict(source='20180406122924_E-challan-generation-1.jpg',show=True)
print(result)
# Out:
# image 1/1 /home/nikhil/projects/traffic violation detection/Helmet/20180406122924_E-challan-generation-1.jpg: 192x512 (no detections), 177.9ms
# Speed: 4.5ms preprocess, 177.9ms inference, 44.6ms postprocess per image at shape (1, 3, 192, 512)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'With Helmet', 1: 'Without Helmet'}
# orig_img: array([[[ 41,  25,  13],
#         [ 45,  29,  17],
#         [ 52,  36,  24],
#         ...,
#         [105,  91,  85],
#         [ 58,  46,  40],
#         [ 48,  38,  31]],
#
#        [[ 16,   1,   0],
#         [ 21,   6,   0],
#         [ 34,  19,  10],
#         ...,
#         [103,  89,  83],
#         [ 44,  32,  26],
#         [ 46,  38,  31]],
#
#        [[ 28,  18,  11],
#         [ 29,  19,  12],
#         [ 36,  26,  19],
#         ...,
#         [ 72,  60,  54],
#         [ 48,  38,  31],
#         [ 64,  58,  53]],
#
# ...

# %%
result.re

# %%
# video_capture = cv2.VideoCapture("BAD DRIVERS He Owns The Road Daily Observations India #74.mp4")
video_capture = cv2.VideoCapture(1)

cv2.namedWindow("Window")

while True:
    ret, frame = video_capture.read()

    result = model(frame)
    

    cv2.imshow("Window", result[0].plot())
    #This breaks on 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video_capture.release()
cv2.destroyAllWindows()
# Out:
# 0: 288x512 (no detections), 115.3ms
# Speed: 8.3ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 Without Helmet, 97.5ms
# Speed: 4.6ms preprocess, 97.5ms inference, 7.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 Without Helmet, 156.6ms
# Speed: 4.2ms preprocess, 156.6ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 Without Helmet, 130.8ms
# Speed: 3.8ms preprocess, 130.8ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 Without Helmet, 104.5ms
# Speed: 3.0ms preprocess, 104.5ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 Without Helmet, 109.3ms
# Speed: 2.2ms preprocess, 109.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 Without Helmet, 106.6ms
# Speed: 3.0ms preprocess, 106.6ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# ...
